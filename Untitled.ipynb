# %%
plt.figure(figsize=(20, 6))

plt.plot(df_graf_visit_grouped_1['date_group'], df_graf_visit_grouped_1['visits'], label='Visits')

plt.grid(which='major', axis='y', linestyle='-', linewidth=1.5, color='gray', alpha=0.7)

plt.title('Visits during marketing active days')

plt.xlabel('date_group')
plt.ylabel('Visits')

plt.xticks(df_graf_visit_grouped_1['date_group'][::7], rotation=45, ha='right')

plt.legend()

plt.show()

# %%
import pandas as pd

# Преобразование данных
grouped_df = df_ads_group_1.groupby(['utm_source', 'utm_medium', 'campaign'])
result_df = pd.DataFrame(columns=['date_group_start', 'date_group_end', 'Ads'])

for group, group_df in grouped_df:
    start_date = group_df['date_group'].min()
    end_date = group_df['date_group'].max()
    ads_name = '-'.join(group)
    
    result_df = pd.concat([result_df, pd.DataFrame({'date_group_start': [start_date],
                                                    'date_group_end': [end_date],
                                                    'Ads': [ads_name]})], ignore_index=True)

# Вывод результата
print(result_df)

# %%
import matplotlib.pyplot as plt

# Ваш существующий код

# Извлечение начальных и конечных дат для каждой рекламной кампании
grouped_df = df_ads_group_1.groupby(['utm_source', 'utm_medium', 'campaign'])
result_df = pd.DataFrame(columns=['date_group_start', 'date_group_end', 'Ads'])

for group, group_df in grouped_df:
    start_date = group_df['date_group'].min()
    end_date = group_df['date_group'].max()
    ads_name = '-'.join(group)
    
    result_df = pd.concat([result_df, pd.DataFrame({'date_group_start': [start_date],
                                                    'date_group_end': [end_date],
                                                    'Ads': [ads_name]})], ignore_index=True)

# Ваш существующий код для построения графика
plt.figure(figsize=(20, 6))
plt.plot(df_graf_visit_grouped_1['date_group'], df_graf_visit_grouped_1['visits'], label='Посещения')

# Выделение периодов рекламных кампаний
for index, row in result_df.iterrows():
    plt.axvspan(row['date_group_start'], row['date_group_end'], facecolor='lightgray', alpha=0.5, label=row['Ads'])

plt.grid(which='major', axis='y', linestyle='-', linewidth=1.5, color='gray', alpha=0.7)
plt.title('Посещения во время активных маркетинговых дней')
plt.xlabel('Группа дат')
plt.ylabel('Посещения')
plt.xticks(df_graf_visit_grouped_1['date_group'][::7], rotation=45, ha='right')
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

# Ваш существующий код

# Извлечение начальных и конечных дат для каждой рекламной кампании
grouped_df = df_ads_group_1.groupby(['utm_source', 'utm_medium', 'campaign'])
result_df = pd.DataFrame(columns=['date_group_start', 'date_group_end', 'Ads'])

for group, group_df in grouped_df:
    start_date = group_df['date_group'].min()
    end_date = group_df['date_group'].max()
    ads_name = '-'.join(group)
    
    result_df = pd.concat([result_df, pd.DataFrame({'date_group_start': [start_date],
                                                    'date_group_end': [end_date],
                                                    'Ads': [ads_name]})], ignore_index=True)

# Ваш существующий код для построения графика
plt.figure(figsize=(20, 6))
plt.plot(df_graf_visit_grouped_1['date_group'], df_graf_visit_grouped_1['visits'], label='Посещения')

# Выделение периодов рекламных кампаний
for index, row in result_df.iterrows():
    plt.axvspan(row['date_group_start'], row['date_group_end'], facecolor='lightgray', alpha=0.5, label=row['Ads'])

plt.grid(which='major', axis='y', linestyle='-', linewidth=1.5, color='gray', alpha=0.7)
plt.title('Посещения во время активных маркетинговых дней')
plt.xlabel('Группа дат')
plt.ylabel('Посещения')
plt.xticks(df_graf_visit_grouped_1['date_group'][::7], rotation=45, ha='right')
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

# Ваш существующий код

# Извлечение начальных и конечных дат для каждой рекламной кампании
grouped_df = df_ads_group_1.groupby(['utm_source', 'utm_medium', 'campaign'])
result_df = pd.DataFrame(columns=['date_group_start', 'date_group_end', 'Ads'])

for group, group_df in grouped_df:
    start_date = group_df['date_group'].min()
    end_date = group_df['date_group'].max()
    ads_name = '-'.join(group)
    
    result_df = pd.concat([result_df, pd.DataFrame({'date_group_start': [start_date],
                                                    'date_group_end': [end_date],
                                                    'Ads': [ads_name]})], ignore_index=True)

# Ваш существующий код для построения графика
plt.figure(figsize=(20, 6))
plt.plot(df_graf_visit_grouped_1['date_group'], df_graf_visit_grouped_1['visits'], label='Посещения')

# Выделение периодов рекламных кампаний
for index, row in result_df.iterrows():
    plt.axvspan(row['date_group_start'], row['date_group_end'], facecolor='lightgray', alpha=0.5, label=row['Ads'])

plt.grid(which='major', axis='y', linestyle='-', linewidth=1.5, color='gray', alpha=0.7)
plt.title('Посещения во время активных маркетинговых дней')
plt.xlabel('Группа дат')
plt.ylabel('Посещения')
plt.xticks(df_graf_visit_grouped_1['date_group'][::7], rotation=45, ha='right')
plt.legend()

plt.show()
